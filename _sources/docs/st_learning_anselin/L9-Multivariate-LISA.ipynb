# %% [markdown]
# # Multivariate LISA
# ## Multivariate Spatial Autocorrelation
# ### The multivariate spatial autocorrelation Problem
# ![image.png](attachment:91f5dd8b-6bfb-4912-b676-0158141700e3.png)

# %% [markdown]
# ## Multivariate extensions of Moran's I
# ![image.png](attachment:f56e76ff-f05f-44a3-9241-d98777fe8a70.png)

# %% [markdown]
# ## Multivariate local Geary (Anselin 2019)
# ### Definition
# ![image.png](attachment:2990b9d6-c635-4bca-8e63-9b699823712d.png)
# ![image.png](attachment:7abe80c7-1afb-4c26-9939-d1a862a1b8fc.png)

# %% [markdown]
# ### Inference
# ![image.png](attachment:cb1086aa-b1e2-433a-8914-703541911ac2.png)

# %% [markdown]
# ### Interpretation
# ![image.png](attachment:e4d5d42b-907f-4d95-a18e-7f909230ff23.png)

# %% [markdown]
# ### Visualization
# ![image.png](attachment:739a1dc1-04e3-4402-84a5-051c0116aaba.png)

# %% [markdown]
# ## Local neighbor match test (Anselin and Li, 2020)
# ![image.png](attachment:7c32ba60-b7af-4916-b84e-3ce3e0d29015.png)

# %% [markdown]
# ### This is a test
